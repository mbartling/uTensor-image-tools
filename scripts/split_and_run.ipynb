# %%
import cv2
import matplotlib.pyplot as plt

# %%
img_path = '..\\data\\final_test_images\\7.jpg'
# reading image
im = cv2.imread(img_path)
# bgr to rgb
im = im[:, :, [2,1,0]]

n_rows = 3
n_columns = 5
M = im.shape[0]//n_rows
N = im.shape[1]//n_columns

tiles = []
for x in range(0,im.shape[0],M):
    for y in range(0,im.shape[1],N):
        if  (x+M<im.shape[0]+M/2) and (y+N<im.shape[1]+N/2):        
            tiles.append(im[x:x+M,y:y+N])
            print(x,x+M)
            print(y,y+N)            
            plt.imshow(im[x:x+M,y:y+N])
            plt.show()
# Out:
# 0 180
# 0 54
# 0 180
# 54 108
# 0 180
# 108 162
# 0 180
# 162 216
# 0 180
# 216 270
# 180 360
# 0 54
# 180 360
# 54 108
# 180 360
# 108 162
# 180 360
# 162 216
# 180 360
# 216 270
# 360 540
# 0 54
# 360 540
# 54 108
# 360 540
# 108 162
# 360 540
# 162 216
# 360 540
# 216 270

# %%
for image in tiles:
    # image preprocess
    float_caster = tf.cast(image, tf.float32)
    dims_expander = tf.expand_dims(float_caster, 0);
    resized = tf.image.resize_bilinear(dims_expander, [input_height, input_width])
    normalized = tf.divide(tf.subtract(resized, [input_mean]), [input_std])
    sess = tf.Session()
    result = sess.run(normalized)
    plt.imshow(t.reshape(32,32,3))
    plt.show()
    
    with tf.Session(graph=graph) as sess:
        start = time.time()
        results = sess.run(output_operation.outputs[0],
                          {input_operation.outputs[0]: t})
        end=time.time()
    results = np.squeeze(results)

    top_k = results.argsort()[-5:][::-1]
    labels = load_labels(label_file)

    print('\nEvaluation time (1-image): {:.3f}s\n'.format(end-start))
    template = "{} (score={:0.5f})"
    for i in top_k:
        print(template.format(labels[i], results[i]))
